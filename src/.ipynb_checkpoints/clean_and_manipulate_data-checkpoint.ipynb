# %% [markdown]
# Let's clean up the data so that later on would be a lot easier to work with it and the operations would make more sense.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load data

# %%
calls = pd.read_csv('../data/callsforservicefiltered.csv', header=0, low_memory=True, 
                    memory_map=True)
print(len(calls))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d1efcbd6082f> in <module>()
#       1 calls = pd.read_csv('../data/callsforservicefiltered.csv', header=0, low_memory=True,
# ----> 2                     memory_map=True)
#       3 print(len(calls))
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'../data/callsforservicefiltered.csv' does not exist

# %% [markdown]
# ## 1. Filter out rows where cancelled calls field = True, report only field = True
# Eliminate calls that were either cancelled or their type was report only (someone called to report).

# %%
calls = calls[calls.rptonly != True]
calls = calls[calls.cancelled != True]
print(len(calls))
# Out:
# 1085198

# %% [markdown]
# ## 2. Filter out rows where nature = Transport to Animal Shelter
# This has to be done in order to avoid later redundancy.<br>
# This type of calls are received also from Guilford's county outside population AND the location is assigned arbitrary.<br>
# These calls CAN be used as a sign of volume, but they don't bring any meaning to the story.

# %%
calls = calls[calls.nature != 'TRANSPORT TO ANIMAL SHELTER']
print(len(calls))
# Out:
# 1067326

# %% [markdown]
# ## 3. Split calltime into more than one field.
# Split the calltime field to <b>year</b>, <b>month</b>, <b>dayOfMonth</b>, and <b>hour</b>.<br>
# In order to do that, we need to convert it to a datetime format that is easier to deal with using pandas.to_datetime.<br>
# After finishing we are dropping it and the timeclose field. (As we have the duration of the call in another field).
# Also, we are renaming the calldow field to become dayOfWeek.

# %%
calls['calltime'] = pd.to_datetime(calls.calltime)
calls['year'] = calls.calltime.apply(lambda x: x.date().year)
calls['month'] = calls.calltime.apply(lambda x: x.date().month)
calls['dayOfMonth'] = calls.calltime.apply(lambda x: x.date().day)
calls['hour'] = calls.calltime.apply(lambda x: x.time().hour)
calls = calls.rename(columns={'calldow' : 'dayOfWeek'})
calls = calls.drop(columns = ['timeclose', 'calltime'], axis = 1)
calls
# Out:
#         callsource  city                          nature             nature2  \
# 0             SELF     G                    TRAFFIC STOP                 NaN
# 1             E911     G        HEMORRHAGE / LACERATIONS                 NaN
# 3             E911     W            SEIZURES-CONVULSIONS                 NaN
# 4             E911     W            SEIZURES-CONVULSIONS                 NaN
# 5             E911     G  FALLS-BACK INJURIES(TRAUMATIC)                 NaN
# 6             E911     G                     SICK PERSON                 NaN
# 7             SELF    ST                    TRAFFIC STOP                 NaN
# 8             W911     H                      CHEST PAIN                 NaN
# 9            PHONE    SU                DOMESTIC DISPUTE                 NaN
# 10            SELF     G         LEGAL PAPER / COMPLAINT                 NaN
# 11            E911     G              BREATHING PROBLEMS                 NaN
# 12            E911     G                     SICK PERSON                 NaN
# 13            E911     G           LAW ASSISTANCE NEEDED                 NaN
# 14            SELF     G              SUSPICIOUS SUBJECT                 NaN
# 15            E911     G              BREATHING PROBLEMS                 NaN
# 16           PHONE   CLI                       FOLLOW UP                 NaN
# 17            E911     G             SUSPICIOUS ACTIVITY                 NaN
# 18            SELF    SU   CITIZEN ASSIST / SERVICE CALL                 NaN
# 19            E911     G                  HEART PROBLEMS                 NaN
# 20           PHONE     G          CONVALESCENT TRANSPORT                 NaN
# 21            SELF     G                    TRAFFIC STOP                 NaN
# 22            E911     G                  ASSAULT / RAPE                 NaN
# 23            SELF     P                    TRAFFIC STOP                 NaN
# 24            XFER  ALAM                      MUTUAL AID                 NaN
# 25            E911     G  FALLS-BACK INJURIES(TRAUMATIC)                 NaN
# 26           PHONE  ALAM                      MUTUAL AID                 NaN
# 27           PHONE     G      NOISE DISTURBANCE OR PARTY                 NaN
# 28           PHONE     H          CONVALESCENT TRANSPORT                 NaN
# 29            SELF    ST                    TRAFFIC STOP                 NaN
# 30           PHONE   CLI                       FOLLOW UP                 NaN
# ...            ...   ...                             ...                 ...
# 1105853       SELF     W                    TRAFFIC STOP        TRAFFIC STOP
# 1105854      PHONE     G  FALLS-BACK INJURIES(TRAUMATIC)                 NaN
# 1105855       E911     G                     SICK PERSON                 NaN
# 1105856       W911     P       BACK PAIN (NON-TRAUMATIC)                 NaN
# 1105857       W911     G              BREATHING PROBLEMS                 NaN
# 1105858       W911     G              BREATHING PROBLEMS                 NaN
# 1105859       E911     B             SUSPICIOUS ACTIVITY                 NaN
# 1105860       W911     B    EMS RESPONSE - NON EMERGENCY                 NaN
# 1105861       E911     G    OVERDOSE-INGESTION-POISONING                 NaN
# 1105862       E911    SU            SEIZURES-CONVULSIONS                 NaN
# 1105863       E911    SU            SEIZURES-CONVULSIONS                 NaN
# 1105864       E911   REI        HEMORRHAGE / LACERATIONS                 NaN
# 1105865       SELF     W                    TRAFFIC STOP        TRAFFIC STOP
# 1105866       E911   REI        HEMORRHAGE / LACERATIONS                 NaN
# 1105867       W911     H                  HEART PROBLEMS                 NaN
# 1105869      PHONE     J      NOISE DISTURBANCE OR PARTY                 NaN
# 1105870       W911     H       ABDOMINAL PAIN / PROBLEMS                 NaN
# 1105871       W911     H                      CHEST PAIN                 NaN
# 1105872       W911     G          ALLERGIES-HIVES-STINGS                 NaN
# 1105873       SELF     P                    TRAFFIC STOP                 NaN
# 1105874       SELF     G              SUSPICIOUS SUBJECT  SUSPICIOUS SUBJECT
# 1105875      PHONE     G          CONVALESCENT TRANSPORT                 NaN
# 1105876      PHONE     W             SUSPICIOUS ACTIVITY                 NaN
# 1105877       SELF     J                    TRAFFIC STOP        TRAFFIC STOP
# 1105878       SELF    SU                    TRAFFIC STOP        TRAFFIC STOP
# 1105879       E911     G             SUSPICIOUS ACTIVITY                 NaN
# 1105880       W911     G  FALLS-BACK INJURIES(TRAUMATIC)                 NaN
# 1105881       W911     G  FALLS-BACK INJURIES(TRAUMATIC)                 NaN
# 1105882       SELF     H                    TRAFFIC STOP        TRAFFIC STOP
# 1105883       XFER     H        EMS RESPONSE - EMERGENCY                 NaN
#
#         priority  rptonly service agency district statbeat  ...  secsdi2ar  \
# 0              1    False     LAW   GCSD      SD3     SD34  ...          0
# 1              4    False     EMS    EMS       B6      B06  ...        393
# 3              1    False     EMS    EMS       B5      B05  ...        854
# 4              P    False    FIRE    GCF     ALAM     ST44  ...        677
# 5              3    False     EMS    EMS      B4B      B04  ...          0
# 6              4    False     EMS    EMS       B1      B01  ...        224
# 7              1    False     LAW   GCSD      SD1     SD16  ...          0
# 8              1    False     EMS    EMS       B2      B02  ...        277
# 9              1    False     LAW   GCSD      SD1     SD12  ...        290
# 10             2    False     LAW   GCSD     GPD1     P110  ...          0
# 11             1    False     EMS    EMS       B6      B06  ...        604
# 12             4    False     EMS    EMS       B6      B06  ...        210
# 13             2    False     LAW   GCSD      SD3     SD34  ...        196
# 14             2    False     LAW   GCSD     GPD3     P340  ...          0
# 15             P    False    FIRE    GCF     PCSF     ST24  ...        264
# 16             9    False     LAW   GCSD      SD3     SD35  ...         76
# 17             2    False     LAW   GCSD      SD3     SD35  ...        180
# 18             7    False    FIRE    GCF     SMFD     ST29  ...          0
# 19             1    False     EMS    EMS      B3A      B03  ...        473
# 20             5    False     EMS    EMS      B4A      B04  ...          0
# 21             1    False     LAW   GCSD      SD3     SD33  ...          0
# 22             3    False     EMS    EMS       B1      B01  ...        646
# 23             1    False     LAW   GCSD      SD3     SD35  ...          0
# 24             2    False    FIRE    GCF      NaN      NaN  ...        745
# 25             3    False     EMS    EMS      B3A      B03  ...        298
# 26             2    False    FIRE    GCF      NaN      NaN  ...        726
# 27             3    False     LAW   GCSD      SD3     SD33  ...         45
# 28             5    False     EMS    EMS       B2      B02  ...        442
# 29             1    False     LAW   GCSD      SD1     SD16  ...          0
# 30             9    False     LAW   GCSD      SD3     SD35  ...        407
# ...          ...      ...     ...    ...      ...      ...  ...        ...
# 1105853        1    False     LAW   GCSD      SD2     SD23  ...          0
# 1105854        4    False     EMS    EMS       B1      B01  ...        767
# 1105855        4    False     EMS    EMS      B3A      B03  ...        219
# 1105856        4    False     EMS    EMS       B6      B06  ...        976
# 1105857        1    False     EMS    EMS      B4B      B04  ...        899
# 1105858        1    False    FIRE    GCF     FD13     ST58  ...        320
# 1105859        2    False     LAW   GCSD      SD1     SD13  ...        963
# 1105860        4    False     EMS    EMS      B4B      B04  ...       1022
# 1105861        1    False     EMS    EMS      B4B      B04  ...       1045
# 1105862        2    False     EMS    EMS      B4B      B04  ...        445
# 1105863        4    False    FIRE    GCF     SMFD     ST29  ...        285
# 1105864        3    False     EMS    EMS      B59      B59  ...        495
# 1105865        1    False     LAW   GCSD      SD2     SD23  ...          0
# 1105866        4    False    FIRE    GCF     NEFD     ST32  ...        473
# 1105867        1    False     EMS    EMS       B2      B02  ...        282
# 1105869        3    False     LAW   GCSD      SD3     SD34  ...        185
# 1105870        4    False     EMS    EMS       B2      B02  ...        461
# 1105871        1    False     EMS    EMS       B2      B02  ...        479
# 1105872        1    False     EMS    EMS      B3A      B03  ...        600
# 1105873        1    False     LAW   GCSD      SD3     SD36  ...          0
# 1105874        2    False     LAW   GCSD      SD3     SD35  ...          0
# 1105875        5    False     EMS    EMS      B4A      B04  ...        755
# 1105876        2    False     LAW   GCSD      SD2     SD23  ...         78
# 1105877        1    False     LAW   GCSD      SD3     SD34  ...          0
# 1105878        1    False     LAW   GCSD      SD1     SD15  ...          0
# 1105879        2    False     LAW   GCSD     GPD2     P230  ...        541
# 1105880        1    False     EMS    EMS       B6      B06  ...        626
# 1105881        4    False    FIRE    GCF     ALAM     ST54  ...        252
# 1105882        1    False     LAW   GCSD     HPPD     HPPD  ...          0
# 1105883        2    False     EMS    EMS       B2      B02  ...          0
#
#         secsar2tr secsar2lc  secsrt2dsp secstr2lc  firstdisp  year  month  \
# 0               0       651           0         0       S335  2012      7
# 1            1881      2454          43       965       M261  2012      7
# 3            1457      4522          30      3918         M2  2012      7
# 4               0       900           8         0        E44  2012      7
# 5               0         0          10         0       M241  2012      7
# 6            1253      2295          29      1267       M211  2012      7
# 7               0       112           0         0       S314  2012      7
# 8            1043      2090          17      1323       M221  2012      7
# 9               0      1109         102         0       S314  2012      7
# 10              0      3734           0         0       S324  2012      7
# 11              0       511          56         0       MA32  2012      7
# 12            640      2015          37      1585       MA32  2012      7
# 13              0       496          54         0       S331  2012      7
# 14              0       165           0         0       S432  2012      7
# 15              0      1058          14         0        E24  2012      7
# 16              0       835          73         0       S335  2012      7
# 17              0      2143          29         0       S334  2012      7
# 18              0       205           0         0        DC9  2012      7
# 19           1792      3943           9      2624       M251  2012      7
# 20           1279      3141         605      1862       MA32  2012      7
# 21              0       442           0         0       S331  2012      7
# 22           1209      1691          21      1128       M211  2012      7
# 23              0      1249           0         0       S335  2012      7
# 24              0     20029         152         0       C231  2012      7
# 25              0       630          19         0       M231  2012      7
# 26              0     34724         147         0        E38  2012      7
# 27              0       287          77         0       S331  2012      7
# 28           1198      2121          46      1365       MA37  2012      7
# 29              0       520           0         0       S314  2012      7
# 30              0      1588          23         0       S335  2012      7
# ...           ...       ...         ...       ...        ...   ...    ...
# 1105853         0      1479           0         0       S223  2018      7
# 1105854         0       793          13         0       MA22  2018      7
# 1105855         0      1438          21         0       M235  2018      7
# 1105856      2263      4559          24      3272         M2  2018      7
# 1105857      2753      4616          37      2762       M251  2018      7
# 1105858         0      1849           8         0        E58  2018      7
# 1105859         0      1126         251         0       S601  2018      7
# 1105860         0       891         107         0        DS1  2018      7
# 1105861         0      1023          70         0       M232  2018      7
# 1105862      2030      5560          20      3530         M1  2018      7
# 1105863         0      1838          15         0     TN2901  2018      7
# 1105864      2582      4442          29      2355         M5  2018      7
# 1105865         0      1670           0         0       S223  2018      7
# 1105866         0      1291          14         0     TN3201  2018      7
# 1105867      2013      4343          36      2612       M235  2018      7
# 1105869         0       540          23         0       S338  2018      7
# 1105870      1057      2360          21      1763       M222  2018      7
# 1105871      1280      2618          25      1817       M235  2018      7
# 1105872      1720      3614          10      2494       M130  2018      7
# 1105873      1820      3579           0      1759       S589  2018      7
# 1105874         0       751           0         0       S331  2018      7
# 1105875      1590      1662         544       826       MA22  2018      7
# 1105876         0      2152          24         0       S221  2018      7
# 1105877         0       716           1         0       S338  2018      7
# 1105878         0      5535           0         0       S318  2018      7
# 1105879         0      1071           0         0       S331  2018      7
# 1105880      2944      4648           8      2331       M241  2018      7
# 1105881         0      1902           5         0        E54  2018      7
# 1105882         0       387           0         0       S338  2018      7
# 1105883         0         0          75         0       M262  2018      7
#
#          dayOfMonth  hour
# 0                 1     0
# 1                 1     0
# 3                 1     0
# 4                 1     0
# 5                 1     0
# 6                 1     0
# 7                 1     0
# 8                 1     0
# 9                 1     0
# 10                1     0
# 11                1     0
# 12                1     0
# 13                1     0
# 14                1     0
# 15                1     0
# 16                1     0
# 17                1     0
# 18                1     0
# 19                1     1
# 20                1     1
# 21                1     1
# 22                1     1
# 23                1     1
# 24                1     2
# 25                1     2
# 26                1     2
# 27                1     2
# 28                1     2
# 29                1     2
# 30                1     2
# ...             ...   ...
# 1105853          31    22
# 1105854          31    22
# 1105855          31    22
# 1105856          31    22
# 1105857          31    22
# 1105858          31    22
# 1105859          31    22
# 1105860          31    22
# 1105861          31    22
# 1105862          31    22
# 1105863          31    22
# 1105864          31    22
# 1105865          31    22
# 1105866          31    22
# 1105867          31    22
# 1105869          31    23
# 1105870          31    23
# 1105871          31    23
# 1105872          31    23
# 1105873          31    23
# 1105874          31    23
# 1105875          31    23
# 1105876          31    23
# 1105877          31    23
# 1105878          31    23
# 1105879          31    23
# 1105880          31    23
# 1105881          31    23
# 1105882          31    23
# 1105883          31    23
#
# [1067326 rows x 33 columns]

# %% [markdown]
# ## 4. Drop unnecessary Columns
# Remove unnecessary fields related to location as: statbeat, ra. To do this we use the pandas function to just drop a column. So the column statbeat and ra was dropped.

# %%
calls.drop(columns = ['statbeat','ra'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-64e35da6b1e8> in <module>()
# ----> 1 calls.drop(columns = ['statbeat','ra'])
#
# NameError: name 'calls' is not defined
